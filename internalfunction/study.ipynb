# %% [markdown]
# LEVEL 0 — What is a Backend? (STARTING FROM ZERO)
#
# When you open Swiggy:
# - You click buttons
# - App sends request
# - Backend decides what to do
# - Backend sends response
#
# Backend = logic + data + rules

# %% [markdown]
# LEVEL 1 — Python Basics We Need (VERY SMALL)
#
# You only need:
# - variables
# - functions
# - classes
# - lists & dictionaries

# %%
#Example (read slowly)
name = "Priyanshu"
age = 22
print(name, age)

# %% [markdown]
# LEVEL 2 — What Data Exists in Swiggy?
#
# Think like a human 👇
#
# Swiggy has:
# - Users
# - Restaurants
# - Food items
# - Orders
# - Delivery partners
#
# These are objects.

# %% [markdown]
# LEVEL 3 — First Class (USER)

# %%
class User:
    def __init__(self, user_id, name):
        self.user_id = user_id
        self.name = name

# %%
# Create a user
user1 = User(1, "Priyanshu")
print(user1.name)

# %% [markdown]
# Meaning:
# - class = blueprint
# - user1 = real user

# %% [markdown]
# LEVEL 4 — Restaurant & Food (VERY BASIC)

# %%
class Food:
    def __init__(self, name, price):
        self.name = name
        self.price = price


class Restaurant:
    def __init__(self, name):
        self.name = name
        self.menu = []   # list of food

    def add_food(self, food):
        self.menu.append(food)

# %%
# Create restaurant
pizza = Food("Pizza", 250)
burger = Food("Burger", 150)

rest = Restaurant("Dominos")
rest.add_food(pizza)
rest.add_food(burger)

for food in rest.menu:
    print(food.name, food.price)

# %% [markdown]
# Meaning:
# - List stores multiple items
# - Restaurant owns menu

# %% [markdown]
# LEVEL 5 — What is an Order? (CORE CONCEPT)
#
# - Order = User + Restaurant + Food + Status

# %%
class Order:
    def __init__(self, order_id, user, restaurant, food_list):
        self.order_id = order_id
        self.user = user
        self.restaurant = restaurant
        self.food_list = food_list
        self.status = "CREATED"

# %% [markdown]
# Create an order

# %%
order1 = Order(1, user1, rest, [pizza, burger])
print(order1.status)

# %% [markdown]
# LEVEL 6 — Order Service (LOGIC LAYER)
#
# Now we create brain of system.

# %%
class OrderService:
    def __init__(self):
        self.orders = {}
        self.next_id = 1

    def place_order(self, user, restaurant, food_list):
        order = Order(self.next_id, user, restaurant, food_list)
        self.orders[self.next_id] = order
        self.next_id += 1
        print("Order placed:", order.order_id)
        return order

# %% [markdown]
# Use it

# %%
service = OrderService()
order = service.place_order(user1, rest, [pizza])

# %% [markdown]
# You just built:
# - Memory storage
# - Order creation
# - Backend service

# %% [markdown]
# LEVEL 7 — Why SYSTEM DESIGN Exists?
#
# Problem:
# - Too many users
# - Too many orders
# - Backend becomes slow
#
# So we add:
# - Cache
# - Rate limiting
# - Queue
# - Load balancing
#
# One by one.

# %% [markdown]
# LEVEL 8 — CACHE (DON’T PANIC)
#
# Cache = temporary memory
#
# Why?
#
# Same restaurant menu is requested again & again.

# %%
class Cache:
    def __init__(self):
        self.data = {}

    def get(self, key):
        return self.data.get(key)

    def set(self, key, value):
        self.data[key] = value

# %% [markdown]
# Use cache

# %%
cache = Cache()

def get_menu(restaurant):
    menu = cache.get(restaurant.name)
    if menu:
        print("From cache")
        return menu

    print("From database")
    cache.set(restaurant.name, restaurant.menu)
    return restaurant.menu

# %% [markdown]
# LEVEL 9 — RATE LIMITING (VERY SLOWLY)
#
# Problem:
# User clicks order button 100 times.
#
# Solution:
# Allow only 3 requests in 10 seconds.

# %%
import time

class RateLimiter:
    def __init__(self):
        self.calls = {}

    def allow(self, user_id):
        now = time.time()

        if user_id not in self.calls:
            self.calls[user_id] = []

        self.calls[user_id] = [t for t in self.calls[user_id] if now - t < 10]

        if len(self.calls[user_id]) < 3:
            self.calls[user_id].append(now)
            return True
        return False

# %% [markdown]
# Use it

# %%
rl = RateLimiter()

if rl.allow(user1.user_id):
    service.place_order(user1, rest, [pizza])
else:
    print("Too many requests")
